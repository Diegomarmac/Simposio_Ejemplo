# %%
import pandas as pd
import scipy.stats as stats

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/con_inconsistencias/general/full.csv')

df.head()
# Out:
#    Unnamed: 0 registro_nacional        fecha_reporte         fecha_evento  \
# 0           0      desaparecido  2011-12-10 10:30:00  2009-09-02 02:30:00
# 1           1      desaparecido  2012-03-01 10:00:00  2011-12-28 12:00:00
# 2           2      desaparecido  2011-12-19 11:20:00  2011-12-17 09:00:00
# 3           3      desaparecido  2012-02-01 11:41:00  2011-12-14 11:00:00
# 4           4      desaparecido  2012-06-01 12:00:00  2012-05-01 11:15:00
#
#      estado clave_estado                 municipio clave_municipio  \
# 0  tlaxcala           29                  tlaxcala              33
# 1    colima            6          villa_de_alvarez              10
# 2  tlaxcala           29  la_magdalena_tlaltelulco              48
# 3    colima            6                   tecoman               9
# 4    colima            6          villa_de_alvarez              10
#
#   nacionalidad estatus_migratorio  ... tipo_de_cejas tamano_de_la_boca  barba  \
# 0     mexicana    no_especificado  ...           NaN               NaN    NaN
# 1     mexicana                NaN  ...           NaN               NaN    NaN
# 2     mexicana    no_especificado  ...           NaN               NaN    NaN
# 3     mexicana    no_especificado  ...           NaN            grande    NaN
# 4     mexicana                NaN  ...           NaN               NaN    NaN
#
#   bigote         submarca tipo_denuncia     tipo_de_evento  \
# 0    NaN  no_especificado           NaN  eventos_validados
# 1    NaN  no_especificado           NaN  eventos_validados
# 2    NaN  no_especificado           NaN  eventos_validados
# 3    NaN  no_especificado           NaN  eventos_validados
# 4    NaN  no_especificado           NaN  eventos_validados
#
#                  tipo_causal clasificacion_causal causal
# 0                          _                    _      _
# 1                          _                    _      _
# 2  ausencia_involuntaria____           accidentes      _
# 3                          _                    _      _
# 4                          _                    _      _
#
# [5 rows x 71 columns]

# %%
stats.zscore(df.estado.value_counts())
# Out:
# estado
# guanajuato             3.370212
# mexico                 2.873751
# tamaulipas             1.967793
# sinaloa                1.561958
# chihuahua              0.963275
# jalisco                0.611144
# nuevo_leon             0.585818
# puebla                 0.560796
# baja_california        0.311192
# sonora                 0.282814
# ciudad_de_mexico       0.256878
# aguascalientes         0.082033
# guerrero              -0.050092
# colima                -0.068706
# coahuila              -0.141024
# chiapas               -0.154450
# michoacan             -0.166350
# queretaro             -0.286575
# quintana_roo          -0.393679
# durango               -0.428465
# veracruz              -0.452876
# morelos               -0.483390
# hidalgo               -0.540756
# campeche              -0.577983
# zacatecas             -0.591409
# tabasco               -0.602089
# yucatan               -0.638706
# oaxaca                -0.690274
# nayarit               -0.768085
# tlaxcala              -0.773882
# no_especificado       -0.775408
# san_luis_potosi       -0.775713
# baja_california_sur   -0.799209
# texas                 -0.816907
# california            -0.817212
# new_york              -0.817212
# georgia               -0.817212
# Name: count, dtype: float64

# %%
stats.zscore(df.estado.value_counts()).to_csv('data_exported.csv')
